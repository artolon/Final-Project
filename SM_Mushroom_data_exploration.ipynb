# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns

# %%
mushroom_data = pd.read_csv("1987_data.csv")
mushroom_data.head()
# Out:
#   class cap-shape cap-surface cap-color bruises odor gill-attachment  \
# 0     p         x           s         n       t    p               f
# 1     e         x           s         y       t    a               f
# 2     e         b           s         w       t    l               f
# 3     p         x           y         w       t    p               f
# 4     e         x           s         g       f    n               f
#
#   gill-spacing gill-size gill-color  ... stalk-surface-below-ring  \
# 0            c         n          k  ...                        s
# 1            c         b          k  ...                        s
# 2            c         b          n  ...                        s
# 3            c         n          n  ...                        s
# 4            w         b          k  ...                        s
#
#   stalk-color-above-ring stalk-color-below-ring veil-type veil-color  \
# 0                      w                      w         p          w
# ...

# %%
display(mushroom_data.shape)
mushroom_data.info()
# Out:
# (8124, 23)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8124 entries, 0 to 8123
# Data columns (total 23 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   class                     8124 non-null   object
#  1   cap-shape                 8124 non-null   object
#  2   cap-surface               8124 non-null   object
#  3   cap-color                 8124 non-null   object
#  4   bruises                   8124 non-null   object
#  5   odor                      8124 non-null   object
#  6   gill-attachment           8124 non-null   object
#  7   gill-spacing              8124 non-null   object
#  8   gill-size                 8124 non-null   object
#  9   gill-color                8124 non-null   object
#  10  stalk-shape               8124 non-null   object
#  11  stalk-root                8124 non-null   object
#  12  stalk-surface-above-ring  8124 non-null   object
# ...

# %%
mushroom_data.describe()
# Out:
#        class cap-shape cap-surface cap-color bruises  odor gill-attachment  \
# count   8124      8124        8124      8124    8124  8124            8124
# unique     2         6           4        10       2     9               2
# top        e         x           y         n       f     n               f
# freq    4208      3656        3244      2284    4748  3528            7914
#
#        gill-spacing gill-size gill-color  ... stalk-surface-below-ring  \
# count          8124      8124       8124  ...                     8124
# unique            2         2         12  ...                        4
# top               c         b          b  ...                        s
# freq           6812      5612       1728  ...                     4936
#
#        stalk-color-above-ring stalk-color-below-ring veil-type veil-color  \
# count                    8124                   8124      8124       8124
# unique                      9                      9         1          4
# ...

# %%
# checking mushroom class distribution across dataset

count = mushroom_data['class'].value_counts()
count.index = ["Edible","Poisonous"]

colors = sns.color_palette('prism')

plt.figure(figsize=(10,8))

plt.pie(count.values ,labels=count.index, startangle=90, shadow=True, autopct='%1.2f%%',  colors=colors)

plt.title('Number of poisonous/edible mushrooms')
plt.show()

# %% [markdown]
# ##### Dataset classifies Mushrooms as edible(e) or poisonous(p)
# ##### Dataset has 8124 entries with 22 features.
# ##### All features are of datatype object but from description it is evident that all are categorical data. Hence need to change the data type.
# ##### Dataset has almost equal entried across both classes.
# ##### Below table outlines all feature attributes:
#
# | | Column Name | Attribute Information |
# | --- | --- | --- |
# |1. | cap-shape | bell=b,   conical=c,   convex=x,    flat=f,    knobbed=k,   sunken=s |
# |2. | cap-surface | fibrous=f, grooves=g, scaly=y,  smooth=s |
# |3. | cap-color | brown=n, buff=b, cinnamon=c, gray=g, green=r, pink=p, purple=u, red=e, white=w, yellow=y |
# |4. | bruises?| bruises=t, no=f |
# |5. | odor | almond=a, anise=l, creosote=c, fishy=y, foul=f, musty=m, none=n, pungent=p, spicy=s |
# |6. | gill-attachment | attached=a, descending=d, free=f, notched=n |
# |7. | gill-spacing | close=c, crowded=w, distant=d |
# |8. | gill-size | broad=b, narrow=n |
# |9. | gill-color | black=k, brown=n, buff=b, chocolate=h, gray=g, green=r, orange=o, pink=p, purple=u, red=e, white=w, yellow=y |
# |10.| stalk-shape | enlarging=e, tapering=t |
# |11.| stalk-root | bulbous=b, club=c, cup=u, equal=e, rhizomorphs=z, rooted=r, missing=? |
# |12.| stalk-surface-above-ring | fibrous=f, scaly=y, silky=k, smooth=s |
# |13.| stalk-surface-below-ring | fibrous=f, scaly=y, silky=k, smooth=s |
# |14.| stalk-color-above-ring | brown=n, buff=b, cinnamon=c, gray=g, orange=o, pink=p, red=e, white=w, yellow=y |
# |15.| stalk-color-below-ring | brown=n, buff=b, cinnamon=c, gray=g, orange=o, pink=p, red=e, white=w, yellow=y |
# |16.| veil-type | partial=p, universal=u |
# |17.| veil-color | brown=n, orange=o, white=w, yellow=y |
# |18.| ring-number | none=n, one=o, two=t |
# |19.| ring-type | cobwebby=c, evanescent=e, flaring=f, large=l, none=n, pendant=p, sheathing=s, zone=z |
# |20.| spore-print-color | black=k, brown=n, buff=b, chocolate=h, green=r, orange=o, purple=u, white=w, yellow=y |
# |21.| population | abundant=a, clustered=c, numerous=n, scattered=s, several=v, solitary=y |
# |22.| habitat | grasses=g, leaves=l, meadows=m, paths=p, urban=u, waste=w, woods=d |

# %% [markdown]
# ## Exploratory Data Analysis

# %% [markdown]
# ### From Abbie's code

# %%
from sklearn.preprocessing import LabelEncoder

mushroom_data = mushroom_data.astype('category')

labelencoder=LabelEncoder()
for c in mushroom_data.columns:
    mushroom_data[c] = labelencoder.fit_transform(mushroom_data[c])

mushroom_data.head()
# Out:
#    class  cap-shape  cap-surface  cap-color  bruises  odor  gill-attachment  \
# 0      1          5            2          4        1     6                1
# 1      0          5            2          9        1     0                1
# 2      0          0            2          8        1     3                1
# 3      1          5            3          8        1     6                1
# 4      0          5            2          3        0     5                1
#
#    gill-spacing  gill-size  gill-color  ...  stalk-surface-below-ring  \
# 0             0          1           4  ...                         2
# 1             0          0           4  ...                         2
# 2             0          0           5  ...                         2
# 3             0          1           5  ...                         2
# 4             1          0           4  ...                         2
#
#    stalk-color-above-ring  stalk-color-below-ring  veil-type  veil-color  \
# ...

# %%
mushroom_data_m = pd.melt(mushroom_data,'class', var_name='Characteristics')
mushroom_data_m['class'].replace({0:'Edible', 1:'Poisonous'}, inplace=True)
fig, ax = plt.subplots(figsize=(20,8))
sns.violinplot(x='Characteristics', y='value', hue='class', split = True, data=mushroom_data_m, palette = 'prism')
features = mushroom_data.drop(['class'],axis = 1)
ax.set_xticklabels(rotation = 90, labels = list(features.columns), size=12)
plt.show()

# %% [markdown]
# ##### Below features do not show significant value distribution across classes
#     * gill-attachment
#     * gill-spacing
#     * gill-size
#     * veil-type
#     * veil-color
#     * ring-number
# ##### Hence we will drop these columns and then check correlation

# %%
mushroom_features = mushroom_data.drop(['gill-attachment', 'gill-spacing', 'gill-size', 'veil-type', 'veil-color', 'ring-number'],axis=1)
mushroom_features.shape
# Out:
# (8124, 17)

# %%
# Checking heatmap
fig, ax = plt.subplots(figsize=(20,10))

corr = mushroom_features.corr()
sns.heatmap(corr, annot=True)
plt.show()
